# %% [markdown]
# **UK USED CAR DATA**

# %%
import pandas as pd
import numpy as np
import plotly.express as px
import matplotlib.pyplot as plt
import seaborn as sns

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
df = pd.read_csv("/content/drive/MyDrive/DATASET/audi.csv")
df
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0        A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1        A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2        A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3        A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4        A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0
# ...     ...   ...    ...          ...      ...      ...  ...   ...         ...
# 10663    A3  2020  16999       Manual     4018   Petrol  145  49.6         1.0
# 10664    A3  2020  16999       Manual     1978   Petrol  150  49.6         1.0
# 10665    A3  2020  17199       Manual      609   Petrol  150  49.6         1.0
# 10666    Q3  2017  19499    Automatic     8646   Petrol  150  47.9         1.4
# 10667    Q3  2016  15999       Manual    11855   Petrol  150  47.9         1.4
#
# ...

# %%
df.columns
# Out:
# Index(['model', 'year', 'price', 'transmission', 'mileage', 'fuelType', 'tax',
#        'mpg', 'engineSize'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10668 entries, 0 to 10667
# Data columns (total 9 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   model         10668 non-null  object
#  1   year          10668 non-null  int64
#  2   price         10668 non-null  int64
#  3   transmission  10668 non-null  object
#  4   mileage       10668 non-null  int64
#  5   fuelType      10668 non-null  object
#  6   tax           10668 non-null  int64
#  7   mpg           10668 non-null  float64
#  8   engineSize    10668 non-null  float64
# dtypes: float64(2), int64(4), object(3)
# memory usage: 750.2+ KB

# %%
df.dtypes
# Out:
# model            object
# year              int64
# price             int64
# transmission     object
# mileage           int64
# fuelType         object
# tax               int64
# mpg             float64
# engineSize      float64
# dtype: object

# %%
df.shape
# Out:
# (10668, 9)

# %% [markdown]
# **# This dataset contains 10668 rows and 9 columns.**

# %%
df.duplicated().sum()
# Out:
# 103

# %% [markdown]
# **# 103 Duplicate rows are thier**

# %% [markdown]
# **Duplicate rows removal**

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0        A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1        A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2        A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3        A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4        A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0
# ...     ...   ...    ...          ...      ...      ...  ...   ...         ...
# 10663    A3  2020  16999       Manual     4018   Petrol  145  49.6         1.0
# 10664    A3  2020  16999       Manual     1978   Petrol  150  49.6         1.0
# 10665    A3  2020  17199       Manual      609   Petrol  150  49.6         1.0
# 10666    Q3  2017  19499    Automatic     8646   Petrol  150  47.9         1.4
# 10667    Q3  2016  15999       Manual    11855   Petrol  150  47.9         1.4
#
# ...

# %%
df.shape
# Out:
# (10565, 9)

# %% [markdown]
# **# After duplicate rows removal, Dataset contains 10565 rows and 9 columns.**

# %%
df.head(5)
# Out:
#   model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0    A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 1    A6  2016  16500    Automatic    36203   Diesel   20  64.2         2.0
# 2    A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 3    A4  2017  16800    Automatic    25952   Diesel  145  67.3         2.0
# 4    A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0

# %%
df.tail(5)
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 10663    A3  2020  16999       Manual     4018   Petrol  145  49.6         1.0
# 10664    A3  2020  16999       Manual     1978   Petrol  150  49.6         1.0
# 10665    A3  2020  17199       Manual      609   Petrol  150  49.6         1.0
# 10666    Q3  2017  19499    Automatic     8646   Petrol  150  47.9         1.4
# 10667    Q3  2016  15999       Manual    11855   Petrol  150  47.9         1.4

# %% [markdown]
# **Petrol car data**

# %%
df[df["fuelType"] == "Petrol"]
# Out:
#       model  year  price transmission  mileage fuelType  tax   mpg  engineSize
# 0        A1  2017  12500       Manual    15735   Petrol  150  55.4         1.4
# 2        A1  2016  11000       Manual    29946   Petrol   30  55.4         1.4
# 4        A3  2019  17300       Manual     1998   Petrol  145  49.6         1.0
# 5        A1  2016  13900    Automatic    32260   Petrol   30  58.9         1.4
# 8        A3  2015  10200       Manual    46112   Petrol   20  60.1         1.4
# ...     ...   ...    ...          ...      ...      ...  ...   ...         ...
# 10663    A3  2020  16999       Manual     4018   Petrol  145  49.6         1.0
# 10664    A3  2020  16999       Manual     1978   Petrol  150  49.6         1.0
# 10665    A3  2020  17199       Manual      609   Petrol  150  49.6         1.0
# 10666    Q3  2017  19499    Automatic     8646   Petrol  150  47.9         1.4
# 10667    Q3  2016  15999       Manual    11855   Petrol  150  47.9         1.4
#
# [5000 rows x 9 columns]

# %% [markdown]
# **No. of cars per year**

# %%
px.area(df.groupby('year').count(),df.groupby('year').count().index, 'model', title= 'No. of cars per year').update_layout(xaxis_title = 'year', yaxis_title = 'No. of cars')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **# In year 2019, Maximum no. of cars are registered(3139)**

# %% [markdown]
# **Average car price per year**

# %%
px.line(df.groupby('year').mean(),df.groupby('year').count().index, 'price', title= 'Average car price per year').update_layout(xaxis_title = 'year', yaxis_title = 'price(£)')
# Out:
# <ipython-input-18-c2b087a001fb>:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **# Based on YoY, average price of the cars are increasing from 2008**

# %% [markdown]
# **No. of Audi cars by model**

# %%
px.pie(df, 'model', labels = 'value', title= 'No. of Audi cars by Model').update_traces(textinfo='label+percent+value', textposition='inside')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **# Audi's A3 model holds maximum percentage(18.1%) with 1917 no. of cars.**

# %%
df['model'].value_counts()
# Out:
#  A3     1917
#  Q3     1379
#  A4     1375
#  A1     1337
#  A5      874
#  Q5      864
#  Q2      810
#  A6      748
#  Q7      394
#  TT      336
#  A7      122
#  A8      118
#  Q8       69
#  RS6      39
#  RS3      33
#  RS4      31
#  RS5      28
#  R8       28
#  S3       18
#  SQ5      16
#  S4       12
#  SQ7       8
#  S8        4
#  S5        3
#  A2        1
#  RS7       1
# Name: model, dtype: int64

# %% [markdown]
# **No. of cars by model**

# %%
px.bar(df.groupby('model').count() , df.groupby('model').count().index, 'price',text='year', title= 'Audi Car Data').update_layout(xaxis_title = 'model', yaxis_title = 'No. of cars')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **From the bar chart, we can say that "Audi A3" is most common car & "Audi A2" and "Audi RS7" is least interested car in UK.**

# %%
plt.scatter(df["year"], df["model"], c = "g")
plt.xlabel("year")
plt.ylabel("model")
plt.title("model/year")
# Out:
# Text(0.5, 1.0, 'model/year')

# %%
plt.plot(df["year"], df["transmission"], "m *")

# %%
plt.plot(df["year"], df["fuelType"], "r +")

# %%
plt.subplot(2,2,1)
plt.plot(df["year"], df["model"], "g>")
plt.xlabel("year")
plt.ylabel("model")

plt.subplot(2,2,2)
plt.plot(df["year"], df["transmission"], "m+")
plt.xlabel("year")
plt.ylabel("transmission")

plt.subplot(2,2,3)
plt.plot(df["year"], df["fuelType"], "r^")
plt.xlabel("year")
plt.ylabel("fuelType")

plt.subplot(2,2,4)
plt.plot(df["year"], df["mpg"], "b*")
plt.xlabel("year")
plt.ylabel("mpg")
# Out:
# Text(0, 0.5, 'mpg')

# %% [markdown]
# **Car model by fueltype.**

# %%
px.scatter(df.sort_values('year', ascending = True).head(2000), y ='model', x = 'fuelType', color='transmission', hover_data=df.columns, size='year', size_max=30, title = 'Car model by FuelType')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Total price(£) of model by thier fuelType**

# %%
px.pie(df, names='model', values='price', facet_col='fuelType', title='Total price(£) of model by thier fuelType').update_traces(textinfo='label+percent+value', textposition='inside')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **# Audi A3 holds 18% in Petrol varient.**
#
# **# Audi Q5 holds 14.5% in Diesel varient.**
#
# **# Audi Q5 holds 66.1% in Hybrid varient.**

# %% [markdown]
# **Total price(£) of model by thier transmission**

# %%
px.pie(df, names='model', values='price', facet_col='transmission', hole=.3, title='Total price(£) of model by thier transmission').update_traces(textinfo='label+percent+value', textposition='inside')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **# Audi A3 holds 23.1% in Manual varient.**
#
# **# Audi Q7 holds 12.7% in Automatic varient.**
#
# **# Audi Q5 holds 16.3% in Semi-auto varient.**

# %% [markdown]
# **Total enginesize by thier fueltype**

# %%
px.pie(df, names='model', values='engineSize', facet_col='fuelType', hole=.5, title='Total enginesize by thier fueltype').update_traces(textinfo='label+percent+value', textposition='inside')
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **Model wise Average mpg(Miles per gallon)**

# %%
px.bar(df[df['fuelType'] == 'Diesel'].groupby('model').mean().sort_values('year', ascending = True).reset_index(), y= 'model', x='mpg' , orientation = 'h', color= 'engineSize', title= 'model wise Average mpg(Miles per gallon)')
# Out:
# <ipython-input-80-621d72370e69>:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **# Audi A1 has Maximum Average(mean) mpg = 76.60 with enginesize = 1.6L**

# %% [markdown]
# **Total price(£) by model**

# %%
px.funnel(df.groupby('model').sum().sort_values("price", ascending = False).reset_index().head(10),y= 'model', x="price", title = 'Total price by model')
# Out:
# <ipython-input-45-dfe2d6669cf3>:1: FutureWarning:
#
# The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **# Audi A3 is most common car in UK so that thier total price contribution is maximum**

# %%
px.treemap(df[df['price']>100000], path= [px.Constant('Audi Cars'),"model","fuelType","transmission"], values= 'mpg', color='mpg', title="Audi's every models car data")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# **# Only two cars above 100000£ = "Audi R8" & "Audi RS6"**
